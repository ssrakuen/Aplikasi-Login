# %% [markdown]
# <a href="https://colab.research.google.com/github/ssrakuen/Aplikasi-Login/blob/main/Resnet_Models_Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorboard
# !pip install gputil
# Out:
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.15.2)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.64.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.6)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.25.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (67.7.2)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard) (3.2.2)
# Collecting gputil
#   Downloading GPUtil-1.4.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: gputil
#   Building wheel for gputil (setup.py) ... done
#   Created wheel for gputil: filename=GPUtil-1.4.0-py3-none-any.whl size=7394 sha256=4be501e5946765676725c697273d3cca4071ef4a2114792f8b8e2720f5b43f4a
#   Stored in directory: /root/.cache/pip/wheels/a9/8a/bd/81082387151853ab8b6b3ef33426e98f5cbfebc3c397a9d4d0
# Successfully built gputil
# Installing collected packages: gputil
# Successfully installed gputil-1.4.0

# %%
import os
import torch
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from torch.utils.data import DataLoader
from torchvision import transforms, datasets, models
import psutil
import time
from torch.utils.tensorboard import SummaryWriter

# Function to load a model
def load_model(model_path, model_class):
    model = model_class(weights=None)
    model.fc = torch.nn.Linear(model.fc.in_features, 3)  # Adjust based on your number of classes
    model.load_state_dict(torch.load(model_path))
    model.eval()
    return model

# Function to test a model
def test_model(model, test_loader, device):
    y_true = []
    y_pred = []
    start_time = time.time()
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(preds.cpu().numpy())
    end_time = time.time()

    # Metrics
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')
    f1 = f1_score(y_true, y_pred, average='weighted')
    conf_matrix = confusion_matrix(y_true, y_pred)

    # Resource usage
    process = psutil.Process(os.getpid())
    cpu_usage = process.cpu_percent()
    gpu_usage = torch.cuda.memory_allocated(device) / 1024**2  # GPU memory usage in MB
    memory_usage = process.memory_info().rss / 1024**2  # Memory usage in MB

    # Time used in seconds
    time_used = end_time - start_time

    return {
        'confusion_matrix': conf_matrix,
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1': f1,
        'cpu_usage': cpu_usage,
        'gpu_usage': gpu_usage,
        'memory_usage': memory_usage,
        'time_used_seconds': time_used
    }

# Define device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Define data transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Load the test dataset
test_dataset = datasets.ImageFolder(root='/content/drive/MyDrive/Machine_Learning/Datasets/sleep_pose_dataset/A1A2/test', transform=transform)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Define directory paths for saved models
models_dir = '/content/drive/MyDrive/Machine_Learning/modelsA1A2/'

# List all model files in the directory
model_files = [f for f in os.listdir(models_dir) if f.endswith('.pth')]

# Dictionary to map model filenames to their respective classes
model_classes = {
    'resnet18': models.resnet18,
    'resnet34': models.resnet34,
    'resnet50': models.resnet50,
    'resnet101': models.resnet101,
    'resnet152': models.resnet152
}

# TensorBoard writer
writer = SummaryWriter(log_dir='/content/drive/MyDrive/Machine_Learning/runs/A1A2')

# Dictionary to store test results
test_results = {}

# Iterate over each model file and test it
for model_file in model_files:
    model_name = model_file.split('_')[0]
    model_path = os.path.join(models_dir, model_file)

    print(f'Testing {model_name} model from {model_file}')

    # Load model
    model_class = model_classes[model_name]
    model = load_model(model_path, model_class)
    model.to(device)

    # Test model
    result = test_model(model, test_loader, device)
    test_results[model_file] = result  # Use model_file as key to distinguish between models

    # Log the results to TensorBoard
    writer.add_scalar(f'{model_name}/Accuracy', result['accuracy'], 0)
    writer.add_scalar(f'{model_name}/Precision', result['precision'], 0)
    writer.add_scalar(f'{model_name}/Recall', result['recall'], 0)
    writer.add_scalar(f'{model_name}/F1_Score', result['f1'], 0)
    writer.add_scalar(f'{model_name}/CPU_Usage', result['cpu_usage'], 0)
    writer.add_scalar(f'{model_name}/GPU_Usage', result['gpu_usage'], 0)
    writer.add_scalar(f'{model_name}/Memory_Usage', result['memory_usage'], 0)
    writer.add_scalar(f'{model_name}/Time_Used_Seconds', result['time_used_seconds'], 0)

# Save the results to a .npy file
np.save('/content/drive/MyDrive/Machine_Learning/test_stats/test_results.npy', test_results)

# Display test results
for model_file, result in test_results.items():
    print(f'Model File: {model_file}')
    print(f'Confusion Matrix:\n{result["confusion_matrix"]}')
    print(f'Accuracy: {result["accuracy"]:.4f}')
    print(f'Precision: {result["precision"]:.4f}')
    print(f'Recall: {result["recall"]:.4f}')
    print(f'F1 Score: {result["f1"]:.4f}')
    print(f'CPU Usage (%): {result["cpu_usage"]:.2f}')
    print(f'GPU Usage (MB): {result["gpu_usage"]:.2f}')
    print(f'Memory Usage (MB): {result["memory_usage"]:.2f}')
    print(f'Time Used (s): {result["time_used_seconds"]:.2f}')
    print('\n')

# Close the TensorBoard writer
writer.close()
# Out:
# Testing resnet18 model from resnet18_lr0.001_batch16.pth
# Testing resnet18 model from resnet18_lr0.001_batch32.pth
# Testing resnet18 model from resnet18_lr0.001_batch64.pth
# Testing resnet18 model from resnet18_lr0.0001_batch16.pth
# Testing resnet18 model from resnet18_lr0.0001_batch32.pth
# Testing resnet18 model from resnet18_lr0.0001_batch64.pth
# Testing resnet34 model from resnet34_lr0.001_batch16.pth
# Testing resnet34 model from resnet34_lr0.001_batch32.pth
# Testing resnet34 model from resnet34_lr0.001_batch64.pth
# Testing resnet34 model from resnet34_lr0.0001_batch16.pth
# Testing resnet34 model from resnet34_lr0.0001_batch32.pth
# Testing resnet34 model from resnet34_lr0.0001_batch64.pth
# Testing resnet50 model from resnet50_lr0.001_batch16.pth
# Testing resnet50 model from resnet50_lr0.001_batch32.pth
# Testing resnet50 model from resnet50_lr0.001_batch64.pth
# Testing resnet50 model from resnet50_lr0.0001_batch16.pth
# Testing resnet50 model from resnet50_lr0.0001_batch32.pth
# Testing resnet50 model from resnet50_lr0.0001_batch64.pth
# Testing resnet101 model from resnet101_lr0.001_batch16.pth
# Testing resnet101 model from resnet101_lr0.001_batch32.pth
# Testing resnet101 model from resnet101_lr0.001_batch64.pth
# Testing resnet101 model from resnet101_lr0.0001_batch16.pth
# Testing resnet101 model from resnet101_lr0.0001_batch32.pth
# Testing resnet101 model from resnet101_lr0.0001_batch64.pth
# Testing resnet152 model from resnet152_lr0.001_batch16.pth
# Testing resnet152 model from resnet152_lr0.001_batch32.pth
# Testing resnet152 model from resnet152_lr0.001_batch64.pth
# Testing resnet152 model from resnet152_lr0.0001_batch16.pth
# Testing resnet152 model from resnet152_lr0.0001_batch32.pth
# Testing resnet152 model from resnet152_lr0.0001_batch64.pth
# Model File: resnet18_lr0.001_batch16.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 64.58
# Memory Usage (MB): 1506.11
# Time Used (s): 3.68
#
#
# Model File: resnet18_lr0.001_batch32.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 63.45
# Memory Usage (MB): 1506.11
# Time Used (s): 3.69
#
#
# Model File: resnet18_lr0.001_batch64.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 64.08
# Memory Usage (MB): 1506.11
# Time Used (s): 3.86
#
#
# Model File: resnet18_lr0.0001_batch16.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 63.45
# Memory Usage (MB): 1506.11
# Time Used (s): 3.27
#
#
# Model File: resnet18_lr0.0001_batch32.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 64.94
# Memory Usage (MB): 1506.08
# Time Used (s): 3.22
#
#
# Model File: resnet18_lr0.0001_batch64.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 64.32
# Memory Usage (MB): 1506.08
# Time Used (s): 3.39
#
#
# Model File: resnet34_lr0.001_batch16.pth
# Confusion Matrix:
# [[182   2   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 0.9965
# Precision: 0.9965
# Recall: 0.9965
# F1 Score: 0.9965
# CPU Usage (%): 0.00
# GPU Usage (MB): 102.68
# Memory Usage (MB): 1506.06
# Time Used (s): 3.92
#
#
# Model File: resnet34_lr0.001_batch32.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 102.92
# Memory Usage (MB): 1506.05
# Time Used (s): 3.69
#
#
# Model File: resnet34_lr0.001_batch64.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 103.54
# Memory Usage (MB): 1506.05
# Time Used (s): 3.96
#
#
# Model File: resnet34_lr0.0001_batch16.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 102.05
# Memory Usage (MB): 1506.05
# Time Used (s): 3.79
#
#
# Model File: resnet34_lr0.0001_batch32.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 102.68
# Memory Usage (MB): 1506.05
# Time Used (s): 3.77
#
#
# Model File: resnet34_lr0.0001_batch64.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 102.05
# Memory Usage (MB): 1506.05
# Time Used (s): 4.27
#
#
# Model File: resnet50_lr0.001_batch16.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 112.07
# Memory Usage (MB): 1506.05
# Time Used (s): 4.34
#
#
# Model File: resnet50_lr0.001_batch32.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   1 193]]
# Accuracy: 0.9982
# Precision: 0.9982
# Recall: 0.9982
# F1 Score: 0.9982
# CPU Usage (%): 0.00
# GPU Usage (MB): 110.70
# Memory Usage (MB): 1506.05
# Time Used (s): 4.32
#
#
# Model File: resnet50_lr0.001_batch64.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   1 193]]
# Accuracy: 0.9982
# Precision: 0.9982
# Recall: 0.9982
# F1 Score: 0.9982
# CPU Usage (%): 0.00
# GPU Usage (MB): 112.07
# Memory Usage (MB): 1506.05
# Time Used (s): 4.40
#
#
# Model File: resnet50_lr0.0001_batch16.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 111.32
# Memory Usage (MB): 1506.05
# Time Used (s): 4.23
#
#
# Model File: resnet50_lr0.0001_batch32.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   1 193]]
# Accuracy: 0.9982
# Precision: 0.9982
# Recall: 0.9982
# F1 Score: 0.9982
# CPU Usage (%): 0.00
# GPU Usage (MB): 112.07
# Memory Usage (MB): 1506.05
# Time Used (s): 4.48
#
#
# Model File: resnet50_lr0.0001_batch64.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 110.70
# Memory Usage (MB): 1506.05
# Time Used (s): 4.23
#
#
# Model File: resnet101_lr0.001_batch16.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 183.99
# Memory Usage (MB): 1506.05
# Time Used (s): 5.48
#
#
# Model File: resnet101_lr0.001_batch32.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 183.87
# Memory Usage (MB): 1506.05
# Time Used (s): 5.37
#
#
# Model File: resnet101_lr0.001_batch64.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 187   1]
#  [  0   0 194]]
# Accuracy: 0.9982
# Precision: 0.9982
# Recall: 0.9982
# F1 Score: 0.9982
# CPU Usage (%): 0.00
# GPU Usage (MB): 184.99
# Memory Usage (MB): 1394.75
# Time Used (s): 5.64
#
#
# Model File: resnet101_lr0.0001_batch16.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   1 193]]
# Accuracy: 0.9982
# Precision: 0.9982
# Recall: 0.9982
# F1 Score: 0.9982
# CPU Usage (%): 0.00
# GPU Usage (MB): 183.62
# Memory Usage (MB): 1419.88
# Time Used (s): 5.36
#
#
# Model File: resnet101_lr0.0001_batch32.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 185.24
# Memory Usage (MB): 1360.14
# Time Used (s): 5.68
#
#
# Model File: resnet101_lr0.0001_batch64.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 184.99
# Memory Usage (MB): 1360.16
# Time Used (s): 5.25
#
#
# Model File: resnet152_lr0.001_batch16.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  1   0 193]]
# Accuracy: 0.9982
# Precision: 0.9982
# Recall: 0.9982
# F1 Score: 0.9982
# CPU Usage (%): 0.00
# GPU Usage (MB): 243.75
# Memory Usage (MB): 1390.57
# Time Used (s): 6.71
#
#
# Model File: resnet152_lr0.001_batch32.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 244.62
# Memory Usage (MB): 1390.95
# Time Used (s): 6.62
#
#
# Model File: resnet152_lr0.001_batch64.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 243.87
# Memory Usage (MB): 1509.54
# Time Used (s): 6.42
#
#
# Model File: resnet152_lr0.0001_batch16.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 243.75
# Memory Usage (MB): 1473.40
# Time Used (s): 6.73
#
#
# Model File: resnet152_lr0.0001_batch32.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 243.87
# Memory Usage (MB): 1510.27
# Time Used (s): 6.56
#
#
# Model File: resnet152_lr0.0001_batch64.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 244.25
# Memory Usage (MB): 1518.26
# Time Used (s): 6.41

# %%
import numpy as np

# Path to the .npy file
npy_file_path = '/content/drive/MyDrive/Machine_Learning/test_stats/test_results.npy'

# Load the .npy file
test_results = np.load(npy_file_path, allow_pickle=True).item()

# Print the test results
for model_file, result in test_results.items():
    print(f'Model File: {model_file}')
    print(f'Confusion Matrix:\n{result["confusion_matrix"]}')
    print(f'Accuracy: {result["accuracy"]:.4f}')
    print(f'Precision: {result["precision"]:.4f}')
    print(f'Recall: {result["recall"]:.4f}')
    print(f'F1 Score: {result["f1"]:.4f}')
    print(f'CPU Usage (%): {result["cpu_usage"]:.2f}')
    print(f'GPU Usage (MB): {result["gpu_usage"]:.2f}')
    print(f'Memory Usage (MB): {result["memory_usage"]:.2f}')
    print(f'Time Used (s): {result["time_used_seconds"]:.2f}')
    print('\n')
# Out:
# Model File: resnet18_lr0.001_batch16.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 64.58
# Memory Usage (MB): 1502.14
# Time Used (s): 3.89
#
#
# Model File: resnet18_lr0.001_batch32.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 63.45
# Memory Usage (MB): 1502.14
# Time Used (s): 3.35
#
#
# Model File: resnet18_lr0.001_batch64.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 64.20
# Memory Usage (MB): 1502.14
# Time Used (s): 3.24
#
#
# Model File: resnet18_lr0.0001_batch16.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 64.33
# Memory Usage (MB): 1502.14
# Time Used (s): 3.84
#
#
# Model File: resnet18_lr0.0001_batch32.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 64.32
# Memory Usage (MB): 1502.14
# Time Used (s): 3.25
#
#
# Model File: resnet18_lr0.0001_batch64.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 64.08
# Memory Usage (MB): 1502.14
# Time Used (s): 3.23
#
#
# Model File: resnet34_lr0.001_batch16.pth
# Confusion Matrix:
# [[182   2   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 0.9965
# Precision: 0.9965
# Recall: 0.9965
# F1 Score: 0.9965
# CPU Usage (%): 0.00
# GPU Usage (MB): 102.05
# Memory Usage (MB): 1502.14
# Time Used (s): 3.96
#
#
# Model File: resnet34_lr0.001_batch32.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 103.54
# Memory Usage (MB): 1502.14
# Time Used (s): 3.70
#
#
# Model File: resnet34_lr0.001_batch64.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 102.92
# Memory Usage (MB): 1502.14
# Time Used (s): 3.68
#
#
# Model File: resnet34_lr0.0001_batch16.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 103.54
# Memory Usage (MB): 1502.14
# Time Used (s): 4.12
#
#
# Model File: resnet34_lr0.0001_batch32.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 102.05
# Memory Usage (MB): 1502.14
# Time Used (s): 3.68
#
#
# Model File: resnet34_lr0.0001_batch64.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 103.54
# Memory Usage (MB): 1502.14
# Time Used (s): 3.68
#
#
# Model File: resnet50_lr0.001_batch16.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 111.45
# Memory Usage (MB): 1502.14
# Time Used (s): 4.65
#
#
# Model File: resnet50_lr0.001_batch32.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   1 193]]
# Accuracy: 0.9982
# Precision: 0.9982
# Recall: 0.9982
# F1 Score: 0.9982
# CPU Usage (%): 0.00
# GPU Usage (MB): 114.44
# Memory Usage (MB): 1502.14
# Time Used (s): 4.36
#
#
# Model File: resnet50_lr0.001_batch64.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   1 193]]
# Accuracy: 0.9982
# Precision: 0.9982
# Recall: 0.9982
# F1 Score: 0.9982
# CPU Usage (%): 0.00
# GPU Usage (MB): 111.81
# Memory Usage (MB): 1502.14
# Time Used (s): 4.38
#
#
# Model File: resnet50_lr0.0001_batch16.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 115.19
# Memory Usage (MB): 1502.14
# Time Used (s): 4.32
#
#
# Model File: resnet50_lr0.0001_batch32.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   1 193]]
# Accuracy: 0.9982
# Precision: 0.9982
# Recall: 0.9982
# F1 Score: 0.9982
# CPU Usage (%): 0.00
# GPU Usage (MB): 112.06
# Memory Usage (MB): 1502.14
# Time Used (s): 4.21
#
#
# Model File: resnet50_lr0.0001_batch64.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 111.57
# Memory Usage (MB): 1502.14
# Time Used (s): 4.93
#
#
# Model File: resnet101_lr0.001_batch16.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 184.37
# Memory Usage (MB): 1502.64
# Time Used (s): 5.28
#
#
# Model File: resnet101_lr0.001_batch32.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 184.49
# Memory Usage (MB): 1503.16
# Time Used (s): 5.61
#
#
# Model File: resnet101_lr0.001_batch64.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 187   1]
#  [  0   0 194]]
# Accuracy: 0.9982
# Precision: 0.9982
# Recall: 0.9982
# F1 Score: 0.9982
# CPU Usage (%): 0.00
# GPU Usage (MB): 184.12
# Memory Usage (MB): 1503.09
# Time Used (s): 5.34
#
#
# Model File: resnet101_lr0.0001_batch16.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   1 193]]
# Accuracy: 0.9982
# Precision: 0.9982
# Recall: 0.9982
# F1 Score: 0.9982
# CPU Usage (%): 0.00
# GPU Usage (MB): 185.24
# Memory Usage (MB): 1503.09
# Time Used (s): 5.51
#
#
# Model File: resnet101_lr0.0001_batch32.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 183.99
# Memory Usage (MB): 1503.09
# Time Used (s): 5.34
#
#
# Model File: resnet101_lr0.0001_batch64.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 186.12
# Memory Usage (MB): 1503.09
# Time Used (s): 5.40
#
#
# Model File: resnet152_lr0.001_batch16.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  1   0 193]]
# Accuracy: 0.9982
# Precision: 0.9982
# Recall: 0.9982
# F1 Score: 0.9982
# CPU Usage (%): 0.00
# GPU Usage (MB): 243.87
# Memory Usage (MB): 1513.86
# Time Used (s): 6.70
#
#
# Model File: resnet152_lr0.001_batch32.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 245.62
# Memory Usage (MB): 1493.04
# Time Used (s): 6.46
#
#
# Model File: resnet152_lr0.001_batch64.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 243.25
# Memory Usage (MB): 1506.07
# Time Used (s): 6.56
#
#
# Model File: resnet152_lr0.0001_batch16.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 244.62
# Memory Usage (MB): 1472.09
# Time Used (s): 7.09
#
#
# Model File: resnet152_lr0.0001_batch32.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 244.00
# Memory Usage (MB): 1506.09
# Time Used (s): 6.71
#
#
# Model File: resnet152_lr0.0001_batch64.pth
# Confusion Matrix:
# [[184   0   0]
#  [  0 188   0]
#  [  0   0 194]]
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
# CPU Usage (%): 0.00
# GPU Usage (MB): 244.12
# Memory Usage (MB): 1506.09
# Time Used (s): 6.50
